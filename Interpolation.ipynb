# %% [markdown]
# ## Loading packages and datasets

# %%
# importing packages

import numpy as np
import os
import time
from dask import dataframe as dd
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import vitaldb
import csv
from datetime import datetime, time as datetime_time, timedelta
import glob
import sys
import sklearn.neighbors._base

# %%
import fancyimpute as fi

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
def getRootDir():
    """
    Get root folder directory
    :return: root folder directory
    :rtype: path
    """
    rootdir = os.path.abspath(os.curdir)

    return rootdir

# %%
rootdir = getRootDir()
rootdir
# Out:
# '/Users/tselanna/Desktop/Code'

# %%
# Import df2 dataset which was partly imputed (not for BT and other intraop vars though)
df2 = glob.glob(os.path.join(
        rootdir, 'TOSHIBA_HDD/2022_07_05T15_28_54_df2.csv'))
df2 = pd.read_csv(df2[0], dtype={"cormack": 'string'})

# %%
# Import the shrinked dataset from PCA&Shrink where BT was been interpolated already 
df = glob.glob(os.path.join(
        rootdir, 'TOSHIBA_HDD/2022_07_06T14_57_48_1104cases_shrinked_final.csv'))
df = pd.read_csv(df[0], dtype={"cormack": 'string'})

# %%
# Import edited merged dataset for investigative purposes later in the script
merged_df = glob.glob(os.path.join(
        rootdir, '*TOSHIBA_HDD/2022_06_20T13_36_10_Merged_edited.csv'))
merged_df = pd.read_csv(merged_df[0], dtype={"position": 'string', 'cormack':'string', 'airway':'string', 'aline1':'string', 'Solar8000/BT':float})
merged_df
# Out:
#           caseid  subjectid  casestart  caseend  anestart  aneend  opstart  \
# 0              1       5955          0    11520      -540   10860     -540
# 1              1       5955          0    11520      -540   10860     -540
# 2              1       5955          0    11520      -540   10860     -540
# 3              1       5955          0    11520      -540   10860     -540
# 4              1       5955          0    11520      -540   10860     -540
# ...          ...        ...        ...      ...       ...     ...      ...
# 10421465    6385       2278          0    20640      -540   21000     -540
# 10421466    6385       2278          0    20640      -540   21000     -540
# 10421467    6385       2278          0    20640      -540   21000     -540
# 10421468    6385       2278          0    20640      -540   21000     -540
# 10421469    6385       2278          0    20640      -540   21000     -540
#
#           opend     adm      dis  icu_days  death_inhosp   age  sex  height  \
# 0         10380 -236220   627780         0             0  77.0    1   160.2
# 1         10380 -236220   627780         0             0  77.0    1   160.2
# 2         10380 -236220   627780         0             0  77.0    1   160.2
# 3         10380 -236220   627780         0             0  77.0    1   160.2
# 4         10380 -236220   627780         0             0  77.0    1   160.2
# ...         ...     ...      ...       ...           ...   ...  ...     ...
# 10421465  19800 -225600  1675200         0             0  69.0    1   159.3
# 10421466  19800 -225600  1675200         0             0  69.0    1   159.3
# 10421467  19800 -225600  1675200         0             0  69.0    1   159.3
# 10421468  19800 -225600  1675200         0             0  69.0    1   159.3
# 10421469  19800 -225600  1675200         0             0  69.0    1   159.3
#
#           weight   bmi  asa  emop       department      optype  \
# 0           67.5  26.3  2.0     0  General surgery  Colorectal
# 1           67.5  26.3  2.0     0  General surgery  Colorectal
# 2           67.5  26.3  2.0     0  General surgery  Colorectal
# 3           67.5  26.3  2.0     0  General surgery  Colorectal
# 4           67.5  26.3  2.0     0  General surgery  Colorectal
# ...          ...   ...  ...   ...              ...         ...
# 10421465    62.3  24.6  2.0     0  General surgery  Colorectal
# 10421466    62.3  24.6  2.0     0  General surgery  Colorectal
# 10421467    62.3  24.6  2.0     0  General surgery  Colorectal
# 10421468    62.3  24.6  2.0     0  General surgery  Colorectal
# 10421469    62.3  24.6  2.0     0  General surgery  Colorectal
#
#                                                 dx  \
# 0                                    Rectal cancer
# 1                                    Rectal cancer
# 2                                    Rectal cancer
# 3                                    Rectal cancer
# 4                                    Rectal cancer
# ...                                            ...
# 10421465  Colon submucosal tumor, unknown behavior
# 10421466  Colon submucosal tumor, unknown behavior
# 10421467  Colon submucosal tumor, unknown behavior
# 10421468  Colon submucosal tumor, unknown behavior
# 10421469  Colon submucosal tumor, unknown behavior
#
#                                opname     approach   position ane_type  \
# 0              Low anterior resection         Open  Lithotomy  General
# 1              Low anterior resection         Open  Lithotomy  General
# 2              Low anterior resection         Open  Lithotomy  General
# 3              Low anterior resection         Open  Lithotomy  General
# 4              Low anterior resection         Open  Lithotomy  General
# ...                               ...          ...        ...      ...
# 10421465  Ultralow anterior resection  Videoscopic  Lithotomy  General
# 10421466  Ultralow anterior resection  Videoscopic  Lithotomy  General
# 10421467  Ultralow anterior resection  Videoscopic  Lithotomy  General
# 10421468  Ultralow anterior resection  Videoscopic  Lithotomy  General
# 10421469  Ultralow anterior resection  Videoscopic  Lithotomy  General
#
#           preop_htn  preop_dm            preop_ecg preop_pft  preop_hb  \
# 0                 1         0  Normal Sinus Rhythm    Normal      14.1
# 1                 1         0  Normal Sinus Rhythm    Normal      14.1
# 2                 1         0  Normal Sinus Rhythm    Normal      14.1
# 3                 1         0  Normal Sinus Rhythm    Normal      14.1
# 4                 1         0  Normal Sinus Rhythm    Normal      14.1
# ...             ...       ...                  ...       ...       ...
# 10421465          1         0  Normal Sinus Rhythm    Normal      15.2
# 10421466          1         0  Normal Sinus Rhythm    Normal      15.2
# 10421467          1         0  Normal Sinus Rhythm    Normal      15.2
# 10421468          1         0  Normal Sinus Rhythm    Normal      15.2
# 10421469          1         0  Normal Sinus Rhythm    Normal      15.2
#
#           preop_plt  preop_pt  preop_aptt  preop_na  preop_k  preop_gluc  \
# 0             189.0      94.0        33.2     141.0      3.1       134.0
# 1             189.0      94.0        33.2     141.0      3.1       134.0
# 2             189.0      94.0        33.2     141.0      3.1       134.0
# 3             189.0      94.0        33.2     141.0      3.1       134.0
# 4             189.0      94.0        33.2     141.0      3.1       134.0
# ...             ...       ...         ...       ...      ...         ...
# 10421465      239.0     114.0        28.7     144.0      4.0       140.0
# 10421466      239.0     114.0        28.7     144.0      4.0       140.0
# 10421467      239.0     114.0        28.7     144.0      4.0       140.0
# 10421468      239.0     114.0        28.7     144.0      4.0       140.0
# 10421469      239.0     114.0        28.7     144.0      4.0       140.0
#
#           preop_alb  preop_ast  preop_alt  preop_bun  preop_cr cormack airway  \
# 0               4.3       18.0       16.0       10.0      0.82       I   Oral
# 1               4.3       18.0       16.0       10.0      0.82       I   Oral
# 2               4.3       18.0       16.0       10.0      0.82       I   Oral
# 3               4.3       18.0       16.0       10.0      0.82       I   Oral
# 4               4.3       18.0       16.0       10.0      0.82       I   Oral
# ...             ...        ...        ...        ...       ...     ...    ...
# 10421465        3.7       18.0       28.0       19.0      0.84    <NA>   <NA>
# 10421466        3.7       18.0       28.0       19.0      0.84    <NA>   <NA>
# 10421467        3.7       18.0       28.0       19.0      0.84    <NA>   <NA>
# 10421468        3.7       18.0       28.0       19.0      0.84    <NA>   <NA>
# 10421469        3.7       18.0       28.0       19.0      0.84    <NA>   <NA>
#
#           tubesize            iv1        aline1  intraop_ebl  intraop_uo  \
# 0              7.5  Right forearm   Left radial          NaN       300.0
# 1              7.5  Right forearm   Left radial          NaN       300.0
# 2              7.5  Right forearm   Left radial          NaN       300.0
# 3              7.5  Right forearm   Left radial          NaN       300.0
# 4              7.5  Right forearm   Left radial          NaN       300.0
# ...            ...            ...           ...          ...         ...
# 10421465       7.5  Right forearm  Right radial        100.0       250.0
# 10421466       7.5  Right forearm  Right radial        100.0       250.0
# 10421467       7.5  Right forearm  Right radial        100.0       250.0
# 10421468       7.5  Right forearm  Right radial        100.0       250.0
# 10421469       7.5  Right forearm  Right radial        100.0       250.0
#
#           intraop_rbc  intraop_ffp  intraop_crystalloid  intraop_colloid  \
# 0                   0            0                350.0                0
# 1                   0            0                350.0                0
# 2                   0            0                350.0                0
# 3                   0            0                350.0                0
# 4                   0            0                350.0                0
# ...               ...          ...                  ...              ...
# 10421465            0            0               2500.0                0
# 10421466            0            0               2500.0                0
# 10421467            0            0               2500.0                0
# 10421468            0            0               2500.0                0
# 10421469            0            0               2500.0                0
#
#           intraop_ppf  intraop_mdz  intraop_ftn  intraop_rocu  intraop_vecu  \
# 0                 120          0.0          100            70             0
# 1                 120          0.0          100            70             0
# 2                 120          0.0          100            70             0
# 3                 120          0.0          100            70             0
# 4                 120          0.0          100            70             0
# ...               ...          ...          ...           ...           ...
# 10421465          100          0.0            0           100             0
# 10421466          100          0.0            0           100             0
# 10421467          100          0.0            0           100             0
# 10421468          100          0.0            0           100             0
# 10421469          100          0.0            0           100             0
#
#           intraop_eph  intraop_phe  intraop_epi  intraop_ca  anedur  extdur  \
# 0                  10            0            0           0   190.0     8.0
# 1                  10            0            0           0   190.0     8.0
# 2                  10            0            0           0   190.0     8.0
# 3                  10            0            0           0   190.0     8.0
# 4                  10            0            0           0   190.0     8.0
# ...               ...          ...          ...         ...     ...     ...
# 10421465           25           30            0         300   359.0    20.0
# 10421466           25           30            0         300   359.0    20.0
# 10421467           25           30            0         300   359.0    20.0
# 10421468           25           30            0         300   359.0    20.0
# 10421469           25           30            0         300   359.0    20.0
#
#                 los  Primus/CO2  Primus/ETCO2  Primus/FEO2  Primus/FIO2  \
# 0          7.145833         NaN           NaN          NaN          NaN
# 1          7.145833         0.0           NaN          NaN          NaN
# 2          7.145833         0.0           NaN          NaN          NaN
# 3          7.145833         0.0           0.0        100.0        100.0
# 4          7.145833         0.0           NaN          NaN          NaN
# ...             ...         ...           ...          ...          ...
# 10421465  19.159722         0.0           NaN          NaN          NaN
# 10421466  19.159722         0.0           NaN          NaN          NaN
# 10421467  19.159722         0.0           NaN          NaN          NaN
# 10421468  19.159722         0.0           NaN          NaN          NaN
# 10421469  19.159722         NaN           NaN          NaN          NaN
#
#           Primus/INCO2  Primus/MAC  Primus/PEEP_MBAR  Primus/RR_CO2  \
# 0                  NaN         NaN               NaN            NaN
# 1                  NaN         NaN               NaN            NaN
# 2                  NaN         NaN               NaN            NaN
# 3                  0.0         0.0               NaN            NaN
# 4                  NaN         NaN               NaN            NaN
# ...                ...         ...               ...            ...
# 10421465           NaN         NaN               NaN            NaN
# 10421466           NaN         NaN               NaN            NaN
# 10421467           NaN         NaN               NaN            NaN
# 10421468           NaN         NaN               NaN            NaN
# 10421469           NaN         NaN               NaN            NaN
#
#           Primus/SET_FIO2  Primus/SET_INTER_PEEP  Solar8000/BT  \
# 0                     NaN                    NaN           NaN
# 1                     NaN                    NaN           NaN
# 2                     NaN                    NaN          20.9
# 3                     NaN                    NaN           NaN
# 4                     NaN                    NaN          21.0
# ...                   ...                    ...           ...
# 10421465              NaN                    NaN           NaN
# 10421466              NaN                    NaN           NaN
# 10421467              NaN                    NaN           NaN
# 10421468              NaN                    NaN           NaN
# 10421469              NaN                    NaN           NaN
#
#           Solar8000/ETCO2  Solar8000/FEO2  Solar8000/FIO2  Solar8000/HR  \
# 0                     NaN             NaN             NaN           NaN
# 1                     NaN             NaN             NaN          88.0
# 2                     NaN             NaN             NaN           NaN
# 3                     NaN             NaN             NaN          87.0
# 4                     NaN             NaN             NaN           NaN
# ...                   ...             ...             ...           ...
# 10421465              NaN             NaN             NaN           NaN
# 10421466              NaN             NaN             NaN           NaN
# 10421467              NaN             NaN             NaN           NaN
# 10421468              NaN             NaN             NaN           NaN
# 10421469              NaN             NaN             NaN           NaN
#
#           Solar8000/INCO2  Solar8000/NIBP_DBP  Solar8000/NIBP_MBP  \
# 0                     NaN                 NaN                 NaN
# 1                     NaN                 NaN                 NaN
# 2                     NaN                 NaN                 NaN
# 3                     NaN                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 10421465              NaN                 NaN                 NaN
# 10421466              NaN                 NaN                 NaN
# 10421467              NaN                 NaN                 NaN
# 10421468              NaN                 NaN                 NaN
# 10421469              NaN                 NaN                 NaN
#
#           Solar8000/NIBP_SBP  Solar8000/PLETH_HR  Solar8000/PLETH_SPO2  \
# 0                        NaN                 NaN                   NaN
# 1                        NaN                88.0                  96.0
# 2                        NaN                 NaN                   NaN
# 3                        NaN                88.0                  96.0
# 4                        NaN                 NaN                   NaN
# ...                      ...                 ...                   ...
# 10421465                 NaN                 NaN                   NaN
# 10421466                 NaN               298.0                  80.0
# 10421467                 NaN                 NaN                   NaN
# 10421468                 NaN               283.0                  79.0
# 10421469                 NaN                 NaN                   NaN
#
#           Solar8000/RR_CO2  Solar8000/VENT_MAWP  Solar8000/VENT_RR
# 0                      NaN                  NaN                NaN
# 1                      NaN                  0.0                NaN
# 2                      NaN                  NaN                NaN
# 3                      NaN                  0.0                NaN
# 4                      NaN                  NaN                NaN
# ...                    ...                  ...                ...
# 10421465               NaN                  NaN                NaN
# 10421466               NaN                  NaN                NaN
# 10421467               NaN                  NaN                NaN
# 10421468               NaN                  NaN                NaN
# 10421469               NaN                  NaN                NaN
#
# [10421470 rows x 89 columns]

# %%
df2.isna().sum()
# Out:
# caseid                         0
# icu_days                       0
# age                            0
# sex                            0
# height                         0
# weight                         0
# bmi                            0
# asa                        36189
# emop                           0
# department                     0
# optype                         0
# dx                             0
# opname                         0
# approach                       0
# position                       0
# ane_type                       0
# preop_htn                      0
# preop_dm                       0
# preop_ecg                      0
# preop_pft                      0
# preop_hb                   95395
# preop_plt                  89925
# preop_pt                  101750
# preop_aptt                105736
# preop_na                  203798
# preop_k                   203798
# preop_gluc                 86136
# preop_alb                  97370
# preop_ast                  86136
# preop_alt                  86136
# preop_bun                  96857
# preop_cr                  102327
# cormack                        0
# airway                         0
# tubesize                   55924
# iv1                            0
# intraop_uo               1087072
# intraop_rbc                    0
# intraop_ffp                    0
# intraop_crystalloid       201116
# intraop_colloid                0
# intraop_ppf                    0
# intraop_mdz                    0
# intraop_ftn                    0
# intraop_rocu                   0
# intraop_vecu                   0
# intraop_eph                    0
# intraop_phe                    0
# intraop_epi                    0
# intraop_ca                     0
# anedur                         0
# extdur                         0
# los                            0
# Primus/CO2                     0
# Primus/ETCO2                   0
# Primus/FEO2                    0
# Primus/FIO2                    0
# Primus/INCO2                   0
# Primus/MAC                     0
# Primus/PEEP_MBAR             583
# Primus/RR_CO2                  0
# Primus/SET_FIO2                0
# Primus/SET_INTER_PEEP       2566
# Solar8000/ETCO2              439
# Solar8000/FEO2               439
# Solar8000/FIO2               439
# Solar8000/HR                   0
# Solar8000/INCO2              439
# Solar8000/NIBP_DBP             0
# Solar8000/NIBP_MBP             0
# Solar8000/NIBP_SBP             0
# Solar8000/PLETH_HR             0
# Solar8000/PLETH_SPO2           0
# Solar8000/RR_CO2            1429
# Solar8000/VENT_MAWP          810
# Solar8000/VENT_RR              0
# seconds                        0
# intraop_ebl              1079249
# Solar8000/BT              215929
# dtype: int64

# %%
df.isna().sum()
# Out:
# caseid                         0
# icu_days                       0
# age                            0
# sex                            0
# height                         0
# weight                         0
# bmi                            0
# asa                        36189
# emop                           0
# department                     0
# optype                         0
# dx                             0
# opname                         0
# approach                       0
# position                  110725
# ane_type                       0
# preop_htn                      0
# preop_dm                       0
# preop_ecg                      0
# preop_pft                      0
# preop_hb                   95395
# preop_plt                  89925
# preop_pt                  101750
# preop_aptt                105736
# preop_na                  203798
# preop_k                   203798
# preop_gluc                 86136
# preop_alb                  97370
# preop_ast                  86136
# preop_alt                  86136
# preop_bun                  96857
# preop_cr                  102327
# cormack                   344499
# airway                     26342
# tubesize                   55924
# iv1                        27157
# intraop_ebl              1078666
# intraop_uo               1086489
# intraop_rbc                    0
# intraop_ffp                    0
# intraop_crystalloid       201116
# intraop_colloid                0
# intraop_ppf                    0
# intraop_mdz                    0
# intraop_ftn                    0
# intraop_rocu                   0
# intraop_vecu                   0
# intraop_eph                    0
# intraop_phe                    0
# intraop_epi                    0
# intraop_ca                     0
# anedur                         0
# extdur                         0
# los                            0
# Primus/CO2                  3911
# Primus/ETCO2             3083010
# Primus/FEO2              3083039
# Primus/FIO2              3083030
# Primus/INCO2             3083005
# Primus/MAC               3083264
# Primus/PEEP_MBAR         3110120
# Primus/RR_CO2            3095016
# Primus/SET_FIO2          3083295
# Primus/SET_INTER_PEEP    3122021
# Solar8000/BT                   0
# Solar8000/ETCO2           252912
# Solar8000/FEO2            252825
# Solar8000/FIO2            252727
# Solar8000/HR               40729
# Solar8000/INCO2           252827
# Solar8000/NIBP_DBP         29434
# Solar8000/NIBP_MBP           243
# Solar8000/NIBP_SBP         29802
# Solar8000/PLETH_HR         39569
# Solar8000/PLETH_SPO2       39605
# Solar8000/RR_CO2          308791
# Solar8000/VENT_MAWP        80058
# Solar8000/VENT_RR         130847
# seconds                        0
# dtype: int64

# %%
df.shape
# Out:
# (3585370, 79)

# %%
df2.shape
# Out:
# (3586392, 79)

# %% [markdown]
# ## Interpolation Script

# %%
# Perform interpolation on df, a shrinked dataframe where Solar8000/BT NaN have been filled with ffill() and 
# 2 cases have been deleted as their vitals were recorded at a different frequency, causing NaN

# %%
# Function that performs interpolation

def imputInterp(rootdir, df, method="Linear"):
    """Imputation techniques"""
    dfs_imp = []
    neighbors = 10

    pID = df['caseid']

    for i in pID.unique():
        cond = df[pID == i]
        df_pat = cond.dropna(how='all', axis=1)
        col = df_pat.columns

        # Interpolation methods
        """Interpolation with different techniques - linear, pad, nearest, polynomial (order=2), spline (order=5), cubic,
    krogh (too slow), piecewise_polynomial, pchip, akima, cubicspline, from_derivatives"""
        if method == "Linear":
            df_lin_interp = df_pat.interpolate(
                method='linear', axis=0, limit_direction='both')
            df_lin_interp = pd.DataFrame(df_lin_interp, columns=col)
            dfs_imp.append(df_lin_interp)
        elif method == "Iterative":
            df_iter_imp = fi.IterativeImputer().fit_transform(df_pat)
            df_iter_imp = pd.DataFrame(df_iter_imp, columns=df_pat.columns)
            dfs_imp.append(df_iter_imp)

    df_imputation = pd.concat(dfs_imp)
    return(df_imputation)

# %%
# LInear interpolation does not work when using the whole dataset, only when using only number containing variables
imp = imputInterp(rootdir, df=df, method="Linear")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e5b902421c90> in <module>
#       1 # LInear interpolation does not work when using the whole dataset, only when using only number containing variables
# ----> 2 imp = imputInterp(rootdir, df=df, method="Linear")
#
# <ipython-input-12-e598a5570907> in imputInterp(rootdir, df, method)
#      17     krogh (too slow), piecewise_polynomial, pchip, akima, cubicspline, from_derivatives"""
#      18         if method == "Linear":
# ---> 19             df_lin_interp = df_pat.interpolate(
#      20                 method='linear', axis=0, limit_direction='both')
#      21             df_lin_interp = pd.DataFrame(df_lin_interp, columns=col)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7220                 "those NaNs before interpolating."
#    7221             )
# -> 7222         new_data = obj._mgr.interpolate(
#    7223             method=method,
#    7224             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in interpolate(self, **kwargs)
#     591
#     592     def interpolate(self, **kwargs) -> "BlockManager":
# --> 593         return self.apply("interpolate", **kwargs)
#     594
#     595     def shift(self, periods: int, axis: int, fill_value) -> "BlockManager":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in interpolate(self, method, axis, inplace, limit, fill_value, **kwargs)
#    1939         values = self.values if inplace else self.values.copy()
#    1940         return self.make_block_same_class(
# -> 1941             values=values.fillna(value=fill_value, method=method, limit=limit),
#    1942             placement=self.mgr_locs,
#    1943         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/_mixins.py in fillna(self, value, method, limit)
#     238         self: NDArrayBackedExtensionArrayT, value=None, method=None, limit=None
#     239     ) -> NDArrayBackedExtensionArrayT:
# --> 240         value, method = validate_fillna_kwargs(value, method)
#     241
#     242         mask = self.isna()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_validators.py in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     365         raise ValueError("Must specify a fill 'value' or 'method'.")
#     366     elif value is None and method is not None:
# --> 367         method = clean_fill_method(method)
#     368
#     369     elif value is not None and method is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/missing.py in clean_fill_method(method, allow_nearest)
#      80         expecting = "pad (ffill), backfill (bfill) or nearest"
#      81     if method not in valid_methods:
# ---> 82         raise ValueError(f"Invalid fill method. Expecting {expecting}. Got {method}")
#      83     return method
#      84
#
# ValueError: Invalid fill method. Expecting pad (ffill) or backfill (bfill). Got linear

# %%
# Therefore, select variables containing numbers to try interpolation -it works now
dfp = df.select_dtypes(include='number')

# %%
imp = imputInterp(rootdir, df=dfp, method="Linear")

# %%
imp.isna().sum()
# Out:
# caseid                         0
# icu_days                       0
# age                            0
# sex                            0
# height                         0
# weight                         0
# bmi                            0
# asa                        36189
# emop                           0
# preop_htn                      0
# preop_dm                       0
# preop_hb                   95395
# preop_plt                  89925
# preop_pt                  101750
# preop_aptt                105736
# preop_na                  203798
# preop_k                   203798
# preop_gluc                 86136
# preop_alb                  97370
# preop_ast                  86136
# preop_alt                  86136
# preop_bun                  96857
# preop_cr                  102327
# tubesize                   55924
# intraop_uo               1086489
# intraop_rbc                    0
# intraop_ffp                    0
# intraop_crystalloid       201116
# intraop_colloid                0
# intraop_ppf                    0
# intraop_mdz                    0
# intraop_ftn                    0
# intraop_rocu                   0
# intraop_vecu                   0
# intraop_eph                    0
# intraop_phe                    0
# intraop_epi                    0
# intraop_ca                     0
# anedur                         0
# extdur                         0
# los                            0
# Primus/CO2                     0
# Primus/ETCO2                   0
# Primus/FEO2                    0
# Primus/FIO2                    0
# Primus/INCO2                   0
# Primus/MAC                     0
# Primus/PEEP_MBAR               0
# Primus/RR_CO2                  0
# Primus/SET_FIO2                0
# Primus/SET_INTER_PEEP       1544
# Solar8000/BT                   0
# Solar8000/ETCO2                0
# Solar8000/FEO2                 0
# Solar8000/FIO2                 0
# Solar8000/HR                   0
# Solar8000/INCO2                0
# Solar8000/NIBP_DBP             0
# Solar8000/NIBP_MBP             0
# Solar8000/NIBP_SBP             0
# Solar8000/PLETH_HR             0
# Solar8000/PLETH_SPO2           0
# Solar8000/RR_CO2             407
# Solar8000/VENT_MAWP            0
# Solar8000/VENT_RR              0
# seconds                        0
# intraop_ebl              1078666
# dtype: int64

# %%
# Manually interplate the two vital variables that still have NaN
imp['Primus/SET_INTER_PEEP'].interpolate(method="linear", limit_direction='both', inplace=True)

# %%
imp['Solar8000/RR_CO2'].interpolate(method="linear", limit_direction='both', inplace=True)

# %%
# There are no NaN anymore in the intraop vars
imp.isna().sum()
# Out:
# caseid                         0
# icu_days                       0
# age                            0
# sex                            0
# height                         0
# weight                         0
# bmi                            0
# asa                        36189
# emop                           0
# preop_htn                      0
# preop_dm                       0
# preop_hb                   95395
# preop_plt                  89925
# preop_pt                  101750
# preop_aptt                105736
# preop_na                  203798
# preop_k                   203798
# preop_gluc                 86136
# preop_alb                  97370
# preop_ast                  86136
# preop_alt                  86136
# preop_bun                  96857
# preop_cr                  102327
# tubesize                   55924
# intraop_uo               1086489
# intraop_rbc                    0
# intraop_ffp                    0
# intraop_crystalloid       201116
# intraop_colloid                0
# intraop_ppf                    0
# intraop_mdz                    0
# intraop_ftn                    0
# intraop_rocu                   0
# intraop_vecu                   0
# intraop_eph                    0
# intraop_phe                    0
# intraop_epi                    0
# intraop_ca                     0
# anedur                         0
# extdur                         0
# los                            0
# Primus/CO2                     0
# Primus/ETCO2                   0
# Primus/FEO2                    0
# Primus/FIO2                    0
# Primus/INCO2                   0
# Primus/MAC                     0
# Primus/PEEP_MBAR               0
# Primus/RR_CO2                  0
# Primus/SET_FIO2                0
# Primus/SET_INTER_PEEP          0
# Solar8000/BT                   0
# Solar8000/ETCO2                0
# Solar8000/FEO2                 0
# Solar8000/FIO2                 0
# Solar8000/HR                   0
# Solar8000/INCO2                0
# Solar8000/NIBP_DBP             0
# Solar8000/NIBP_MBP             0
# Solar8000/NIBP_SBP             0
# Solar8000/PLETH_HR             0
# Solar8000/PLETH_SPO2           0
# Solar8000/RR_CO2               0
# Solar8000/VENT_MAWP            0
# Solar8000/VENT_RR              0
# seconds                        0
# intraop_ebl              1078666
# dtype: int64

# %%
imp.caseid.nunique()
# Out:
# 1104

# %%
imp.shape
# Out:
# (3585370, 67)

# %%
imp.isna().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (3585370, 79)

# %%
imp.shape
# Out:
# (3585370, 79)

# %%
# Now insert back the categorical variables that were removed to run interpolation

# %%
imp['department'] = df['department']
imp['optype'] = df['optype']
imp['dx'] = df['dx']
imp['opname'] = df['opname']
imp['approach'] = df['approach']
imp['position'] = df['position']
imp['ane_type'] = df['ane_type']
imp['preop_ecg'] = df['preop_ecg']
imp['preop_pft'] = df['preop_pft']
imp['cormack'] = df['cormack']
imp['iv1'] = df['iv1']
imp['airway'] = df['airway']

# %%
# Create new df with variables in the correct order

imp_final = imp[['caseid', 'icu_days', 'age', 'sex', 'height', 'weight', 'bmi', 'asa',
       'emop', 'department', 'optype', 'dx', 'opname', 'approach', 'position',
       'ane_type', 'preop_htn', 'preop_dm', 'preop_ecg', 'preop_pft',
       'preop_hb', 'preop_plt', 'preop_pt', 'preop_aptt', 'preop_na',
       'preop_k', 'preop_gluc', 'preop_alb', 'preop_ast', 'preop_alt',
       'preop_bun', 'preop_cr', 'cormack', 'airway', 'tubesize', 'iv1',
       'intraop_ebl', 'intraop_uo', 'intraop_rbc', 'intraop_ffp',
       'intraop_crystalloid', 'intraop_colloid', 'intraop_ppf', 'intraop_mdz',
       'intraop_ftn', 'intraop_rocu', 'intraop_vecu', 'intraop_eph',
       'intraop_phe', 'intraop_epi', 'intraop_ca', 'anedur', 'extdur', 'los',
       'Primus/CO2', 'Primus/ETCO2', 'Primus/FEO2', 'Primus/FIO2',
       'Primus/INCO2', 'Primus/MAC', 'Primus/PEEP_MBAR', 'Primus/RR_CO2',
       'Primus/SET_FIO2', 'Primus/SET_INTER_PEEP', 'Solar8000/BT',
       'Solar8000/ETCO2', 'Solar8000/FEO2', 'Solar8000/FIO2', 'Solar8000/HR',
       'Solar8000/INCO2', 'Solar8000/NIBP_DBP', 'Solar8000/NIBP_MBP',
       'Solar8000/NIBP_SBP', 'Solar8000/PLETH_HR', 'Solar8000/PLETH_SPO2',
       'Solar8000/RR_CO2', 'Solar8000/VENT_MAWP', 'Solar8000/VENT_RR',
       'seconds']]

# %%
imp_final.caseid.nunique()
# Out:
# 1104

# %%
# No NaN in intraop variables
imp_final.isna().sum()
# Out:
# caseid                         0
# icu_days                       0
# age                            0
# sex                            0
# height                         0
# weight                         0
# bmi                            0
# asa                        36189
# emop                           0
# department                     0
# optype                         0
# dx                             0
# opname                         0
# approach                       0
# position                  110725
# ane_type                       0
# preop_htn                      0
# preop_dm                       0
# preop_ecg                      0
# preop_pft                      0
# preop_hb                   95395
# preop_plt                  89925
# preop_pt                  101750
# preop_aptt                105736
# preop_na                  203798
# preop_k                   203798
# preop_gluc                 86136
# preop_alb                  97370
# preop_ast                  86136
# preop_alt                  86136
# preop_bun                  96857
# preop_cr                  102327
# cormack                   344499
# airway                     26342
# tubesize                   55924
# iv1                        27157
# intraop_ebl              1078666
# intraop_uo               1086489
# intraop_rbc                    0
# intraop_ffp                    0
# intraop_crystalloid       201116
# intraop_colloid                0
# intraop_ppf                    0
# intraop_mdz                    0
# intraop_ftn                    0
# intraop_rocu                   0
# intraop_vecu                   0
# intraop_eph                    0
# intraop_phe                    0
# intraop_epi                    0
# intraop_ca                     0
# anedur                         0
# extdur                         0
# los                            0
# Primus/CO2                     0
# Primus/ETCO2                   0
# Primus/FEO2                    0
# Primus/FIO2                    0
# Primus/INCO2                   0
# Primus/MAC                     0
# Primus/PEEP_MBAR               0
# Primus/RR_CO2                  0
# Primus/SET_FIO2                0
# Primus/SET_INTER_PEEP          0
# Solar8000/BT                   0
# Solar8000/ETCO2                0
# Solar8000/FEO2                 0
# Solar8000/FIO2                 0
# Solar8000/HR                   0
# Solar8000/INCO2                0
# Solar8000/NIBP_DBP             0
# Solar8000/NIBP_MBP             0
# Solar8000/NIBP_SBP             0
# Solar8000/PLETH_HR             0
# Solar8000/PLETH_SPO2           0
# Solar8000/RR_CO2               0
# Solar8000/VENT_MAWP            0
# Solar8000/VENT_RR              0
# seconds                        0
# dtype: int64

# %%
type(imp_final)
# Out:
# pandas.core.frame.DataFrame

# %%
# This variable was erroneously not deleted in earlier stages, so do it now
imp_final = imp_final.drop('cormack', axis=1)

# %%
# Fill the remaining NaN in preop vars with -1
imp_final = imp_final.fillna(-1)

# %%
imp_final.shape
# Out:
# (3585370, 78)

# %%
# Export the final imputed & shrinked df with 1104 cases 

csv_filename = os.path.join(
            "TOSHIBA_HDD", f'{datetime.now().strftime("%Y_%m_%dT%H_%M_%S")}_1104cases_IMP_SHRINK_FINAL.csv')
imp_final.to_csv(csv_filename, encoding='utf-8-sig', index=False)

# %%
imp_final
# Out:
#          caseid  icu_days   age  sex  height  weight   bmi  asa  emop  \
# 0             1         0  77.0    1   160.2    67.5  26.3  2.0     0
# 1             1         0  77.0    1   160.2    67.5  26.3  2.0     0
# 2             1         0  77.0    1   160.2    67.5  26.3  2.0     0
# 3             1         0  77.0    1   160.2    67.5  26.3  2.0     0
# 4             1         0  77.0    1   160.2    67.5  26.3  2.0     0
# ...         ...       ...   ...  ...     ...     ...   ...  ...   ...
# 3585365    6385         0  69.0    1   159.3    62.3  24.6  2.0     0
# 3585366    6385         0  69.0    1   159.3    62.3  24.6  2.0     0
# 3585367    6385         0  69.0    1   159.3    62.3  24.6  2.0     0
# 3585368    6385         0  69.0    1   159.3    62.3  24.6  2.0     0
# 3585369    6385         0  69.0    1   159.3    62.3  24.6  2.0     0
#
#               department      optype  \
# 0        General surgery  Colorectal
# 1        General surgery  Colorectal
# 2        General surgery  Colorectal
# 3        General surgery  Colorectal
# 4        General surgery  Colorectal
# ...                  ...         ...
# 3585365  General surgery  Colorectal
# 3585366  General surgery  Colorectal
# 3585367  General surgery  Colorectal
# 3585368  General surgery  Colorectal
# 3585369  General surgery  Colorectal
#
#                                                dx  \
# 0                                   Rectal cancer
# 1                                   Rectal cancer
# 2                                   Rectal cancer
# 3                                   Rectal cancer
# 4                                   Rectal cancer
# ...                                           ...
# 3585365  Colon submucosal tumor, unknown behavior
# 3585366  Colon submucosal tumor, unknown behavior
# 3585367  Colon submucosal tumor, unknown behavior
# 3585368  Colon submucosal tumor, unknown behavior
# 3585369  Colon submucosal tumor, unknown behavior
#
#                               opname     approach   position ane_type  \
# 0             Low anterior resection         Open  Lithotomy  General
# 1             Low anterior resection         Open  Lithotomy  General
# 2             Low anterior resection         Open  Lithotomy  General
# 3             Low anterior resection         Open  Lithotomy  General
# 4             Low anterior resection         Open  Lithotomy  General
# ...                              ...          ...        ...      ...
# 3585365  Ultralow anterior resection  Videoscopic  Lithotomy  General
# 3585366  Ultralow anterior resection  Videoscopic  Lithotomy  General
# 3585367  Ultralow anterior resection  Videoscopic  Lithotomy  General
# 3585368  Ultralow anterior resection  Videoscopic  Lithotomy  General
# 3585369  Ultralow anterior resection  Videoscopic  Lithotomy  General
#
#          preop_htn  preop_dm            preop_ecg preop_pft  preop_hb  \
# 0                1         0  Normal Sinus Rhythm    Normal      14.1
# 1                1         0  Normal Sinus Rhythm    Normal      14.1
# 2                1         0  Normal Sinus Rhythm    Normal      14.1
# 3                1         0  Normal Sinus Rhythm    Normal      14.1
# 4                1         0  Normal Sinus Rhythm    Normal      14.1
# ...            ...       ...                  ...       ...       ...
# 3585365          1         0  Normal Sinus Rhythm    Normal      15.2
# 3585366          1         0  Normal Sinus Rhythm    Normal      15.2
# 3585367          1         0  Normal Sinus Rhythm    Normal      15.2
# 3585368          1         0  Normal Sinus Rhythm    Normal      15.2
# 3585369          1         0  Normal Sinus Rhythm    Normal      15.2
#
#          preop_plt  preop_pt  preop_aptt  preop_na  preop_k  preop_gluc  \
# 0            189.0      94.0        33.2     141.0      3.1       134.0
# 1            189.0      94.0        33.2     141.0      3.1       134.0
# 2            189.0      94.0        33.2     141.0      3.1       134.0
# 3            189.0      94.0        33.2     141.0      3.1       134.0
# 4            189.0      94.0        33.2     141.0      3.1       134.0
# ...            ...       ...         ...       ...      ...         ...
# 3585365      239.0     114.0        28.7     144.0      4.0       140.0
# 3585366      239.0     114.0        28.7     144.0      4.0       140.0
# 3585367      239.0     114.0        28.7     144.0      4.0       140.0
# 3585368      239.0     114.0        28.7     144.0      4.0       140.0
# 3585369      239.0     114.0        28.7     144.0      4.0       140.0
#
#          preop_alb  preop_ast  preop_alt  preop_bun  preop_cr airway  \
# 0              4.3       18.0       16.0       10.0      0.82   Oral
# 1              4.3       18.0       16.0       10.0      0.82   Oral
# 2              4.3       18.0       16.0       10.0      0.82   Oral
# 3              4.3       18.0       16.0       10.0      0.82   Oral
# 4              4.3       18.0       16.0       10.0      0.82   Oral
# ...            ...        ...        ...        ...       ...    ...
# 3585365        3.7       18.0       28.0       19.0      0.84     -1
# 3585366        3.7       18.0       28.0       19.0      0.84     -1
# 3585367        3.7       18.0       28.0       19.0      0.84     -1
# 3585368        3.7       18.0       28.0       19.0      0.84     -1
# 3585369        3.7       18.0       28.0       19.0      0.84     -1
#
#          tubesize            iv1  intraop_ebl  intraop_uo  intraop_rbc  \
# 0             7.5  Right forearm         -1.0       300.0            0
# 1             7.5  Right forearm         -1.0       300.0            0
# 2             7.5  Right forearm         -1.0       300.0            0
# 3             7.5  Right forearm         -1.0       300.0            0
# 4             7.5  Right forearm         -1.0       300.0            0
# ...           ...            ...          ...         ...          ...
# 3585365       7.5  Right forearm        100.0       250.0            0
# 3585366       7.5  Right forearm        100.0       250.0            0
# 3585367       7.5  Right forearm        100.0       250.0            0
# 3585368       7.5  Right forearm        100.0       250.0            0
# 3585369       7.5  Right forearm        100.0       250.0            0
#
#          intraop_ffp  intraop_crystalloid  intraop_colloid  intraop_ppf  \
# 0                  0                350.0                0          120
# 1                  0                350.0                0          120
# 2                  0                350.0                0          120
# 3                  0                350.0                0          120
# 4                  0                350.0                0          120
# ...              ...                  ...              ...          ...
# 3585365            0               2500.0                0          100
# 3585366            0               2500.0                0          100
# 3585367            0               2500.0                0          100
# 3585368            0               2500.0                0          100
# 3585369            0               2500.0                0          100
#
#          intraop_mdz  intraop_ftn  intraop_rocu  intraop_vecu  intraop_eph  \
# 0                0.0          100            70             0           10
# 1                0.0          100            70             0           10
# 2                0.0          100            70             0           10
# 3                0.0          100            70             0           10
# 4                0.0          100            70             0           10
# ...              ...          ...           ...           ...          ...
# 3585365          0.0            0           100             0           25
# 3585366          0.0            0           100             0           25
# 3585367          0.0            0           100             0           25
# 3585368          0.0            0           100             0           25
# 3585369          0.0            0           100             0           25
#
#          intraop_phe  intraop_epi  intraop_ca  anedur  extdur        los  \
# 0                  0            0           0   190.0     8.0   7.145833
# 1                  0            0           0   190.0     8.0   7.145833
# 2                  0            0           0   190.0     8.0   7.145833
# 3                  0            0           0   190.0     8.0   7.145833
# 3585367                83.0               118.0               106.0
# 3585368                83.0               118.0               106.0
# 3585369                83.0               118.0               105.0
#
#          Solar8000/PLETH_SPO2  Solar8000/RR_CO2  Solar8000/VENT_MAWP  \
# 0                        97.0               5.0                  0.0
# 1                        97.0               5.0                  0.0
# 2                        97.0               5.0                  0.0
# 3                        97.0               5.0                  0.0
# 4                        97.0               5.0                  0.0
# ...                       ...               ...                  ...
# 3585365                 100.0              12.0                  0.0
# 3585366                 100.0              12.0                  0.0
# 3585367                 100.0              12.0                  0.0
# 3585368                 100.0              12.0                  0.0
# 3585369                  98.0              12.0                  0.0
#
#          Solar8000/VENT_RR  seconds
# 0                     18.0       96
# 1                     18.0       98
# 2                     18.0      100
# 3                     18.0      102
# 4                     18.0      104
# ...                    ...      ...
# 3585365               11.0    20076
# 3585366               11.0    20078
# 3585367               11.0    20080
# 3585368               11.0    20082
# 3585369               11.0    20084
#
# [3585370 rows x 78 columns]

# %% [markdown]
# ## This section was used to investigate why interpolation didnt work fully in vars such as BT

# %%
# Linear interpolation doesnt work when using all variables

# %%
# Therfore, select variables containing numbers to try interpolation -it works now
dfx = df2.select_dtypes(include='number')

# %%
df_imp2 = imputInterp(rootdir, df=dfx, method="Linear")

# %%
# 123 cases in the shirnked dataset were not imputed correctly for the BT variable
df_imp2.caseid[df_imp2['Solar8000/BT'].isna()].nunique()
# Out:
# 123

# %%
# Case 5084 is responsible for all the NaN in Solar8000/ETCO2 & FEO2, FIO2, INCO2

df_imp2.caseid[df_imp2['Solar8000/ETCO2'].isna()].unique()
# Out:
# array([5084])

# %%
df_imp2.caseid[df_imp2['Primus/PEEP_MBAR'].isna()].unique()
# Out:
# array([1753])

# %%
df_imp2.caseid[df_imp2['Primus/SET_INTER_PEEP'].isna()].unique()
# Out:
# array([1562, 1753, 2630, 3620, 5084, 6156])

# %%
df_imp2.caseid[df_imp2['Solar8000/RR_CO2'].isna()].unique()
# Out:
# array([1753, 5084, 6156])

# %%
df_imp2.caseid[df_imp2['Solar8000/BT'].isna()].unique()
# Out:
# array([   1,   18,   33,  174,  329,  410,  420,  501,  612,  735,  804,
#         888,  893,  937,  938,  958,  965, 1088, 1156, 1223, 1359, 1434,
#        1438, 1459, 1517, 1562, 1634, 1666, 1721, 1740, 1753, 1796, 1826,
#        1829, 1857, 1860, 1881, 1905, 1911, 1962, 2001, 2032, 2082, 2180,
#        2201, 2287, 2306, 2341, 2345, 2347, 2408, 2565, 2624, 2630, 2712,
#        2829, 3039, 3045, 3064, 3086, 3110, 3176, 3362, 3374, 3398, 3440,
#        3518, 3535, 3620, 3664, 3788, 3801, 3918, 3938, 4007, 4010, 4025,
#        4094, 4103, 4130, 4186, 4269, 4376, 4403, 4423, 4437, 4447, 4523,
#        4524, 4569, 4627, 4636, 4686, 4711, 4736, 4775, 4845, 4884, 4956,
#        5056, 5062, 5081, 5084, 5103, 5221, 5395, 5429, 5452, 5485, 5568,
#        5658, 5711, 5767, 5813, 5888, 5972, 6016, 6021, 6059, 6148, 6156,
#        6288, 6316])

# %%
-236220  627780         0             0  77.0    1   160.2    67.5  26.3
# 296 -236220  627780         0             0  77.0    1   160.2    67.5  26.3
# ...
# 268                 NaN                   NaN               NaN
# 269                86.0                 100.0               NaN
# 270                 NaN                   NaN               NaN
# 271                87.0                 100.0               NaN
# 272                 NaN                   NaN               NaN
# 273                89.0                 100.0               NaN
# 274                 NaN                   NaN               NaN
# 275                89.0                 100.0               NaN
# 276                 NaN                   NaN               NaN
# 277                89.0                 100.0               NaN
# 278                 NaN                   NaN               NaN
# 279                87.0                 100.0               NaN
# 280                 NaN                   NaN               NaN
# 281                86.0                 100.0               NaN
# 282                 NaN                   NaN               NaN
# 283                86.0                 100.0               NaN
# 284                 NaN                   NaN               NaN
# 285                85.0                 100.0               NaN
# 286                 NaN                   NaN               NaN
# 287                85.0                 100.0               NaN
# 288                 NaN                   NaN               NaN
# 289                86.0                 100.0               NaN
# 290                 NaN                   NaN               NaN
# 291                86.0                 100.0               NaN
# 292                 NaN                   NaN               NaN
# 293                86.0                 100.0               NaN
# 294                 NaN                   NaN               NaN
# 295                87.0                 100.0               NaN
# 296                 NaN                   NaN               NaN
# 297                86.0                 100.0               NaN
# 298                 NaN                   NaN               NaN
# 299                86.0                 100.0               NaN
#
#      Solar8000/VENT_MAWP  Solar8000/VENT_RR
# 0                    NaN                NaN
# 1                    0.0                NaN
# 2                    NaN                NaN
# 3                    0.0                NaN
# 4                    NaN                NaN
# 5                    0.0                NaN
# 6                    NaN                NaN
# 7                    0.0                NaN
# 8                    NaN                NaN
# 9                    0.0                NaN
# 10                   NaN                NaN
# 11                   0.0                NaN
# 12                   NaN                NaN
# 13                   0.0                NaN
# 14                   NaN                NaN
# 15                   0.0                NaN
# 16                   NaN                NaN
# 17                   0.0                NaN
# 18                   NaN                NaN
# 19                   0.0                NaN
# 20                   NaN                NaN
# 21                   0.0                NaN
# 22                   NaN                NaN
# 23                   0.0                NaN
# 24                   NaN                NaN
# 25                   0.0                NaN
# 26                   NaN                NaN
# 27                   0.0                NaN
# 28                   NaN                NaN
# 29                   0.0                NaN
# 30                   NaN                NaN
# 31                   0.0                NaN
# 32                   NaN                NaN
# 33                   0.0                NaN
# 34                   NaN                NaN
# 35                   0.0                NaN
# 36                   NaN                NaN
# 37                   0.0                NaN
# 38                   NaN                NaN
# 39                   0.0                NaN
# 40                   NaN                NaN
# 41                   0.0                NaN
# 42                   NaN                NaN
# 43                   0.0                NaN
# 44                   NaN                NaN
# 45                   0.0                NaN
# 46                   NaN                NaN
# 47                   0.0                NaN
# 48                   NaN                NaN
# 49                   0.0                NaN
# 50                   NaN                NaN
# 51                   0.0                NaN
# 52                   NaN                NaN
# 53                   0.0                NaN
# 54                   NaN                NaN
# 55                   0.0                NaN
# 56                   NaN                NaN
# 57                   0.0                NaN
# 58                   NaN                NaN
# 59                   0.0                NaN
# 60                   NaN                NaN
# 61                   0.0                NaN
# 62                   NaN                NaN
# 63                   0.0                NaN
# 64                   NaN                NaN
# 65                   0.0                NaN
# 66                   NaN                NaN
# 67                   0.0                NaN
# 68                   NaN                NaN
# 69                   0.0                NaN
# 70                   NaN                NaN
# 71                   0.0                NaN
# 72                   NaN                NaN
# 73                   0.0                NaN
# 74                   NaN                NaN
# 75                   0.0                NaN
# 76                   NaN                NaN
# 77                   0.0                NaN
# 78                   NaN                NaN
# 79                   0.0                NaN
# 80                   NaN                NaN
# 81                   0.0                NaN
# 82                   NaN                NaN
# 83                   0.0                NaN
# 84                   NaN                NaN
# 85                   0.0                NaN
# 86                   NaN                NaN
# 87                   0.0                NaN
# 88                   NaN                NaN
# 89                   0.0                NaN
# 90                   NaN                NaN
# 91                   0.0                NaN
# 92                   NaN                NaN
# 93                   0.0                NaN
# 94                   NaN                NaN
# 95                   0.0                NaN
# 96                   NaN                NaN
# 97                   0.0                NaN
# 98                   NaN                NaN
# 99                   0.0                NaN
# 100                  NaN                NaN
# 101                  0.0                NaN
# 102                  NaN                NaN
# 103                  0.0                NaN
# 104                  NaN                NaN
# 105                  0.0                NaN
# 106                  NaN                NaN
# 107                  0.0                NaN
# 108                  NaN                NaN
# 109                  0.0                NaN
# 110                  NaN                NaN
# 111                  0.0                NaN
# 112                  NaN                NaN
# 113                  0.0                NaN
# 114                  NaN                NaN
# 115                  0.0                NaN
# 116                  NaN                NaN
# 117                  0.0                NaN
# 118                  NaN                NaN
# 119                  0.0                NaN
# 120                  NaN                NaN
# 121                  0.0                NaN
# 122                  NaN                NaN
# 123                  0.0                NaN
# 124                  NaN                NaN
# 125                  0.0                NaN
# 126                  NaN                NaN
# 127                  0.0                NaN
# 128                  NaN                NaN
# 129                  0.0                NaN
# 130                  NaN                NaN
# 131                  0.0                NaN
# 132                  NaN                NaN
# 133                  0.0                NaN
# 134                  NaN                NaN
# 135                  0.0                NaN
# 136                  NaN                NaN
# 137                  0.0                NaN
# 138                  NaN                NaN
# 139                  0.0                NaN
# 140                  NaN                NaN
# 141                  0.0                NaN
# 142                  NaN                NaN
# 143                  0.0                NaN
# 144                  NaN                NaN
# 145                  0.0                NaN
# 146                  NaN                NaN
# 147                  0.0                NaN
# 148                  NaN                NaN
# 149                  0.0                NaN
# 150                  NaN                NaN
# 151                  0.0                NaN
# 152                  NaN                NaN
# 153                  0.0                NaN
# 154                  NaN                NaN
# 155                  0.0                NaN
# 156                  NaN                NaN
# 157                  0.0                NaN
# 158                  NaN                NaN
# 159                  0.0                NaN
# 160                  NaN                NaN
# 161                  0.0                NaN
# 162                  NaN                NaN
# 163                  0.0                NaN
# 164                  NaN                NaN
# 165                  0.0                NaN
# 166                  NaN                NaN
# 167                  0.0                NaN
# 168                  NaN                NaN
# 169                  0.0                NaN
# 170                  NaN                NaN
# 171                  0.0                NaN
# 172                  NaN                NaN
# 173                  0.0                NaN
# 174                  NaN                NaN
# 175                  0.0                NaN
# 176                  NaN                NaN
# 177                  0.0                NaN
# 178                  NaN                NaN
# 179                  0.0                NaN
# 180                  NaN                NaN
# 181                  0.0                NaN
# 182                  NaN                NaN
# 183                  0.0                NaN
# 184                  NaN                NaN
# 185                  0.0                NaN
# 186                  NaN                NaN
# 187                  0.0                NaN
# 188                  NaN                NaN
# 189                  0.0                NaN
# 190                  NaN                NaN
# 191                  0.0                NaN
# 192                  NaN                NaN
# 193                  0.0                NaN
# 194                  NaN                NaN
# 195                  0.0                NaN
# 196                  NaN                NaN
# 197                  0.0                NaN
# 198                  NaN                NaN
# 199                  0.0                NaN
# 200                  NaN                NaN
# 201                  0.0                NaN
# 202                  NaN                NaN
# 203                  0.0                NaN
# 204                  NaN                NaN
# 205                  0.0                NaN
# 206                  NaN                NaN
# 207                  0.0                NaN
# 208                  NaN                NaN
# 209                  0.0                NaN
# 210                  NaN                NaN
# 211                  0.0                NaN
# 212                  NaN                NaN
# 213                  0.0                NaN
# 214                  NaN                NaN
# 215                  0.0                NaN
# 216                  NaN                NaN
# 217                  0.0                NaN
# 218                  NaN                NaN
# 219                  0.0                NaN
# 220                  NaN                NaN
# 221                  0.0                NaN
# 222                  NaN                NaN
# 223                  0.0                NaN
# 224                  NaN                NaN
# 225                  0.0                NaN
# 226                  NaN                NaN
# 227                  0.0                NaN
# 228                  NaN                NaN
# 229                  0.0                NaN
# 230                  NaN                NaN
# 231                  0.0                NaN
# 232                  NaN                NaN
# 233                  0.0                NaN
# 234                  NaN                NaN
# 235                  0.0                NaN
# 236                  NaN                NaN
# 237                  0.0                NaN
# 238                  NaN                NaN
# 239                  0.0                NaN
# 240                  NaN                NaN
# 241                  0.0                NaN
# 242                  NaN                NaN
# 243                  0.0                NaN
# 244                  NaN                NaN
# 245                  0.0                NaN
# 246                  NaN                NaN
# 247                  0.0                NaN
# 248                  NaN                NaN
# 249                  0.0                NaN
# 250                  NaN                NaN
# 251                  0.0                NaN
# 252                  NaN                NaN
# 253                  0.0                NaN
# 254                  NaN                NaN
# 255                  0.0                NaN
# 256                  NaN                NaN
# 257                  0.0                NaN
# 258                  NaN                NaN
# 259                  0.0                NaN
# 260                  NaN                NaN
# 261                  0.0                NaN
# 262                  NaN                NaN
# 263                  0.0                NaN
# 264                  NaN                NaN
# 265                  0.0                NaN
# 266                  NaN                NaN
# 267                  0.0                NaN
# 268                  NaN                NaN
# 269                  0.0                NaN
# 270                  NaN                NaN
# 271                  0.0                NaN
# 272                  NaN                NaN
# 273                  0.0                NaN
# 274                  NaN                NaN
# 275                  0.0                NaN
# 276                  NaN                NaN
# 277                  0.0                NaN
# 278                  NaN                NaN
# 279                  0.0                NaN
# 280                  NaN                NaN
# 281                  0.0                NaN
# 282                  NaN                NaN
# 283                  0.0                NaN
# 284                  NaN                NaN
# 285                  0.0                NaN
# 286                  NaN                NaN
# 287                  0.0                NaN
# 288                  NaN                NaN
# 289                  0.0                NaN
# 290                  NaN                NaN
# 291                  0.0                NaN
# 292                  NaN                NaN
# 293                  0.0                NaN
# 294                  NaN                NaN
# 295                  0.0                NaN
# 296                  NaN                NaN
# 297                  0.0                NaN
# 298                  NaN                NaN
# 299                  0.0                NaN

# %%
len(df_imp2[df_imp2['caseid'].eq(1)])
# Out:
# 347

# %%
len(merged_df[merged_df['caseid'].eq(1)])
# Out:
# 11542

# %%
merged_df.shape
# Out:
# (10421470, 89)
